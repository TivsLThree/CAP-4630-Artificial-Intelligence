# %% [markdown]
# <a href="https://colab.research.google.com/github/TivsLThree/CAP-4630-Artificial-Intelligence/blob/master/Homework/HW2/HW2P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### f1 with minimum at (0,0,0)

# %%
def f(x, y):
  return  x**2 + y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)

ax.scatter(0,0,0)
ax.plot3D(x,y,f(x,y), 'gray')

# %%
def f(x, y):
  return  x**2 + y**2
fig = plt.figure()
x = np.linspace(-150, 150, 40)
y = np.linspace(-150, 150, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
ax.scatter(0,0,0) # This should be drawing the point but I don't understand
contours = plt.contour(X, Y, Z, 50,cmap='RdGy');
plt.clabel(contours, fontsize = 0);
plt.imshow(Z, extent=[-150,150, -150, 150], origin='lower', cmap='RdGy', alpha = 0.9)
plt.scatter(0,0, c = 'red', marker='o')
plt.show()

# %%
def f(x, y):
  return  x**2 + y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)
X, Y = np.meshgrid(x, y);
ax.contour3D(X, Y, f(X, Y), 25)
ax.plot([0], [0], 0, 'ro')

# %% [markdown]
# ## f2 With maximum at (0,0,0)

# %%
def f(x, y):
  return  -x**2 - 2*y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)

ax.scatter(0,0,0)
ax.plot3D(x,y,f(x,y), 'gray')

# %%
def f(x, y):
  return   -x**2 - 2*y**2
fig = plt.figure()
x = np.linspace(-150, 150, 40)
y = np.linspace(-150, 150, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
contours = plt.contour(X, Y, Z, 50,cmap='RdGy');
plt.clabel(contours, fontsize = 0);
plt.imshow(Z, extent=[-150,150, -150, 150], origin='lower', cmap='RdGy', alpha = 0.9)
plt.scatter(0,0, c = 'red', marker='o')
plt.show()

# %%
def f(x, y):
  return -x**2 - 2*y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)
X, Y = np.meshgrid(x, y);
ax.contour3D(X, Y, f(X, Y), 25)
ax.plot([0], [0], 0, 'ro')

# %% [markdown]
# ## f3 with saddle point at (0,0,0)

# %%
def f(x, y):
  return  x**2- 3*y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)

ax.scatter(0,0,0) 
ax.plot3D(x,y,f(x,y), 'gray')

# %%
def f(x, y):
  return   x**2 - 3*y**2
fig = plt.figure()
x = np.linspace(-150, 150, 40)
y = np.linspace(-150, 150, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
ax.scatter(0,0,0) # This should be drawing the point but I don't understand
contours = plt.contour(X, Y, Z, 50,cmap='RdGy');
plt.clabel(contours, fontsize = 0);
plt.imshow(Z, extent=[-150,150, -150, 150], origin='lower', cmap='RdGy', alpha = 0.9)
plt.scatter(0,0, c = 'red', marker='o')
plt.show()

# %%
def f(x, y):
  return x**2 - 3*y**2
fig = plt.figure()
ax = plt.axes(projection='3d')
p = [[5],
      [0],
      [0]]
x = np.linspace(-150, 150, 80)
y = np.linspace(-150, 150, 80)
X, Y = np.meshgrid(x, y);

ax.contour3D(X, Y, f(X, Y), 25)
ax.plot([0], [0], 0, 'ro')
